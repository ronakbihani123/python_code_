# %% [markdown]
# <a href="https://colab.research.google.com/github/ronakbihani123/python_code_/blob/main/Logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# logistix regression ---> ml model ---> when we have target data as categorical/
# in backend---> activation function ----< sigmoid ----> probability

# we know that probability lies from 0 to 1

# if prob > 0.5 or 1/2  ---> output ---->1
# if prob < 0.5 or 1/2 ---> output ---> 0

# %%
df = pd.read_csv("/content/covid_toy.csv")
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()

# %%
df["fever"] = si.fit_transform(df[["fever"]])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df["gender"] = lb.fit_transform(df["gender"])
df["cough"] = lb.fit_transform(df["cough"])
df["city"] = lb.fit_transform(df["city"])
df["has_covid"] = lb.fit_transform(df["has_covid"])

# %%
df.head(2)
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0
# 1   27       1  100.0      0     1          1

# %%
x = df.drop(columns = ["has_covid"])
y = df["has_covid"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.75

# %%
# confusion metrix ---->
  # TP = ====> HUMAN DETECT AND MACHINE DETECT
  # TN ------> HUMAN NOT DETECT AND MACHINE NOT DETECT
  # FP =====> HUMAN NOT DETECT BUT MACHINE deTECT
  # FN =====> HUMAN DETECT BUT MACHINE NOT DETECT

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[9, 4],
#        [1, 6]])

# %%
df = pd.read_csv("/content/userbehaviour.csv")
df.head()
# Out:
#    userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0    1001                 17.0                       634.0            1
# 1    1002                  0.0                        54.0            0
# 2    1003                 37.0                       207.0            0
# 3    1004                 32.0                       445.0            1
# 4    1005                 45.0                       427.0            1
#
#    Ratings  New Password Request  Last Visited Minutes       Status
# 0        9                     7                  2990    Installed
# 1        4                     8                 24008  Uninstalled
# 2        8                     5                   971    Installed
# 3        6                     2                   799    Installed
# 4        5                     6                  3668    Installed

# %%
df.isnull().sum()
# Out:
# userid                        0
# Average Screen Time           0
# Average Spent on App (INR)    0
# Left Review                   0
# Ratings                       0
# New Password Request          0
# Last Visited Minutes          0
# Status                        0
# dtype: int64

# %%
df.head()
# Out:
#    userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0    1001                 17.0                       634.0            1
# 1    1002                  0.0                        54.0            0
# 2    1003                 37.0                       207.0            0
# 3    1004                 32.0                       445.0            1
# 4    1005                 45.0                       427.0            1
#
#    Ratings  New Password Request  Last Visited Minutes       Status
# 0        9                     7                  2990    Installed
# 1        4                     8                 24008  Uninstalled
# 2        8                     5                   971    Installed
# 3        6                     2                   799    Installed
# 4        5                     6                  3668    Installed

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['Status'] = lb.fit_transform(df['Status'])

# %%
df.head(12)
# Out:
#     userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0     1001                 17.0                       634.0            1
# 1     1002                  0.0                        54.0            0
# 2     1003                 37.0                       207.0            0
# 3     1004                 32.0                       445.0            1
# 4     1005                 45.0                       427.0            1
# 5     1006                 28.0                       599.0            0
# 6     1007                 49.0                       887.0            1
# 7     1008                  8.0                        31.0            0
# 8     1009                 28.0                       741.0            1
# 9     1010                 28.0                       524.0            1
# 10    1011                 44.0                       688.0            1
# 11    1012                 24.0                       466.0            1
#
# ...

# %%
x = df.drop(columns= ["Status"])
y = df["Status"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test , y_train , y_test = train_test_split(x, y , test_size = 0.2 , random_state = 42)

# %%
# what do u mean by imbalance data
# what are the different different techniques to convert imbalance to balance data
# smote , undersampling , oversampling

# %%
# task ---->  imbalance data ko balance krna h  , different different techniques use krni h  ,

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[187,   0],
#        [  0,  13]])

# %%
df = pd.read_csv("/content/placement.csv")
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
x = df.drop(columns=["placed"])
y = df["placed"]

# %%
from sklearn.model_selection import train_test_split

# %%
# assignment ===> virtual environment , uv ,

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
y_test.value_counts()
# Out:
# placed
# 1    10
# 0    10
# Name: count, dtype: int64
